# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict, Annotated
from langchain_core.messages import BaseMessage, HumanMessage
from langchain_google_genai import ChatGoogleGenerativeAI

from langgraph.checkpoint.memory import MemorySaver

# %%
#define state
#reducer function

from langgraph.graph.message import add_messages

class ChatState(TypedDict):

    messages: Annotated[list[BaseMessage], add_messages] 
    #BaseMessage to store all type of messages, User, AI, System, tool   and add_messages reducer to add all the messages

# %%
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

def chat_node(state: ChatState):

    #take user query
    messages = state['messages']

    #send to llm
    response = llm.invoke(messages)

    #response store state
    return {'messages': [response]}

# %%
checkpointer = MemorySaver() #object of memorysaver class

graph = StateGraph(ChatState)

#add nodes
graph.add_node('chat_node', chat_node)


#add edges
graph.add_edge(START, 'chat_node')
graph.add_edge('chat_node', END)

chatbot = graph.compile(checkpointer=checkpointer)

chatbot

# %%
initial_state = {
    'messages':[HumanMessage(content='what is the capital of india?')]
}

chatbot.invoke(initial_state)['messages'][-1].content
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 5
#       1 initial_state = {
#       2     'messages':[HumanMessage(content='what is the capital of india?')]
#       3 }
# ----> 5 chatbot.invoke(initial_state)['messages'][-1].content
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langgraph\pregel\main.py:3068, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, **kwargs)
#    3065 chunks: list[dict[str, Any] | Any] = []
#    3066 interrupts: list[Interrupt] = []
# -> 3068 for chunk in self.stream(
#    3069     input,
#    3070     config,
#    3071     context=context,
#    3072     stream_mode=["updates", "values"]
#    3073     if stream_mode == "values"
#    3074     else stream_mode,
#    3075     print_mode=print_mode,
#    3076     output_keys=output_keys,
#    3077     interrupt_before=interrupt_before,
#    3078     interrupt_after=interrupt_after,
#    3079     durability=durability,
#    3080     **kwargs,
#    3081 ):
#    3082     if stream_mode == "values":
#    3083         if len(chunk) == 2:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langgraph\pregel\main.py:2515, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2498 run_manager = callback_manager.on_chain_start(
#    2499     None,
#    2500     input,
#    2501     name=config.get("run_name", self.get_name()),
#    2502     run_id=config.get("run_id"),
#    2503 )
#    2504 try:
#    2505     # assign defaults
#    2506     (
#    2507         stream_modes,
#    2508         output_keys,
#    2509         interrupt_before_,
#    2510         interrupt_after_,
#    2511         checkpointer,
#    2512         store,
#    2513         cache,
#    2514         durability_,
# -> 2515     ) = self._defaults(
#    2516         config,
#    2517         stream_mode=stream_mode,
#    2518         print_mode=print_mode,
#    2519         output_keys=output_keys,
#    2520         interrupt_before=interrupt_before,
#    2521         interrupt_after=interrupt_after,
#    2522         durability=durability,
#    2523     )
#    2524     if checkpointer is None and durability is not None:
#    2525         warnings.warn(
#    2526             "`durability` has no effect when no checkpointer is present.",
#    2527         )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langgraph\pregel\main.py:2379, in Pregel._defaults(self, config, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability)
#    2377     checkpointer = self.checkpointer
#    2378 if checkpointer and not config.get(CONF):
# -> 2379     raise ValueError(
#    2380         "Checkpointer requires one or more of the following 'configurable' "
#    2381         "keys: thread_id, checkpoint_ns, checkpoint_id"
#    2382     )
#    2383 if CONFIG_KEY_RUNTIME in config.get(CONF, {}):
#    2384     store: BaseStore | None = config[CONF][CONFIG_KEY_RUNTIME].store
#
# ValueError: Checkpointer requires one or more of the following 'configurable' keys: thread_id, checkpoint_ns, checkpoint_id

# %%
while True:
    user_message = input('type here: ')
    print('user:', user_message)

    if user_message.strip().lower() in ['exit', 'quit', 'bye']:
        break
    response = chatbot.invoke({'messages':[HumanMessage(content=user_message)]})

    print('AI:', response['messages'][-1].content)
# Out:
# user: hi
# AI: Hi there! How can I help you today?
# user: what is the capital of india
# AI: The capital of India is **New Delhi**.
# user: okay, what is the capital of spain?
# AI: The capital of Spain is **Madrid**.
# user: good, thanks
# AI: You're welcome! I'm glad I could help.
#
# If you have any more questions or need anything else, just let me know. I'm here to assist you.
# user: what is quantum mechanics
# AI: Quantum mechanics is a fundamental theory in physics that describes the physical properties of nature at the scale of atoms and subatomic particles. It's a bizarre and counter-intuitive realm that governs how things behave at the smallest possible levels, and it's responsible for many of the technologies we rely on today.
#
# Here's a breakdown of its core ideas and why it's so important:
#
# **Key Concepts of Quantum Mechanics:**
#
# *   **Quantization:** This is where the name "quantum" comes from. Many physical properties, like energy, momentum, and angular momentum, are not continuous but come in discrete packets or "quanta." Imagine it like a staircase where you can only stand on specific steps, not anywhere in between. For example, electrons in an atom can only occupy certain energy levels.
#
# *   **Wave-Particle Duality:** This is one of the most mind-bending aspects. Quantum objects, like electrons or photons (light particles), can exhibit characteristics of both waves and particles.
#     *   **Particle-like behavior:** They can be localized, have mass (or momentum for photons), and interact in discrete events.
#     *   **Wave-like behavior:** They can diffract, interfere, and spread out like waves.
#     The famous double-slit experiment beautifully demonstrates this. When you fire particles at a screen with two slits, they create an interference pattern on a detector screen behind it, as if they went through both slits simultaneously as waves.
#
# *   **Superposition:** A quantum system can exist in multiple states *simultaneously* until it is measured. Think of Schrödinger's cat – it's both alive and dead at the same time until you open the box and observe it. In the quantum world, an electron can be in multiple positions or have multiple spins at once.
#
# *   **Uncertainty Principle (Heisenberg's Uncertainty Principle):** It's impossible to know certain pairs of properties of a quantum particle with perfect accuracy at the same time. The more precisely you know one, the less precisely you can know the other. The most famous example is the position and momentum of a particle. If you know exactly where an electron is, you can't know its speed, and vice versa.
#
# *   **Quantum Entanglement:** This is a phenomenon where two or more quantum particles become linked in such a way that their fates are intertwined, no matter how far apart they are. If you measure a property of one entangled particle, you instantly know the corresponding property of the other, even if they are light-years apart. Einstein famously called this "spooky action at a distance."
#
# *   **Probability and Determinism:** Unlike classical physics, which is deterministic (if you know the initial conditions, you can predict the future with certainty), quantum mechanics is inherently probabilistic. We can only calculate the *probability* of a certain outcome occurring. The act of measurement "collapses" the superposition into a single, definite state.
#
# **Why is Quantum Mechanics Important?**
#
# Quantum mechanics isn't just an abstract theoretical curiosity. It's the foundation for much of our modern technology:
#
# *   **Electronics:** The behavior of electrons in semiconductors, which are the building blocks of all modern electronics (computers, smartphones, etc.), is governed by quantum mechanics.
# *   **Lasers:** Lasers, used in everything from barcode scanners to surgery, rely on the principles of quantum mechanics.
# *   **Medical Imaging:** MRI (Magnetic Resonance Imaging) and PET (Positron Emission Tomography) scans are direct applications of quantum phenomena.
# *   **Materials Science:** Understanding the quantum properties of materials allows us to design new materials with specific characteristics.
# *   **Quantum Computing:** This is a burgeoning field that aims to harness quantum phenomena like superposition and entanglement to perform calculations that are impossible for even the most powerful classical computers.
# *   **Chemistry:** The way atoms bond to form molecules is explained by quantum mechanics.
#
# **In Summary:**
#
# Quantum mechanics is a revolutionary theory that replaced classical physics at the atomic and subatomic level. It describes a world that is probabilistic, quantized, and where particles can behave like waves. While it can be challenging to grasp intuitively, its predictions have been repeatedly verified by experiments, and it's essential for understanding and developing many of the technologies that shape our lives.
# user: bye

# %%
while True:
    user_message = input('type here: ')
    print('user:', user_message)

    if user_message.strip().lower() in ['exit', 'quit', 'bye']:
        break
    response = chatbot.invoke({'messages':[HumanMessage(content=user_message)]})

    print('AI:', response['messages'][-1].content)
# Out:
# user: hi
# AI: Hi there! How can I help you today?
# user: my name is deepak
# AI: Hello Deepak! It's nice to meet you. How can I help you today?
# user: tell me my name
# AI: I do not have access to any personal information about you, including your name. I am a large language model, trained by Google.
# user: i am 30 year old
# AI: That's a great age! Thirty is often seen as a significant milestone, a point where many people feel a sense of established adulthood while still having plenty of life ahead of them.
#
# What are your thoughts or feelings about being 30? Is there anything in particular you'd like to discuss or know related to this age? For example, are you thinking about:
#
# *   **Career goals?**
# *   **Personal development?**
# *   **Relationships?**
# *   **Health and well-being?**
# *   **Financial planning?**
# *   **Just reflecting on life?**
#
# I'm here to chat about whatever is on your mind!
# user: what is my age
# AI: I cannot know your age. I am a large language model, an AI, and I do not have access to personal information about you, including your age.
# user: quit

# %%
#after adding MemorySaver
#adding thread, config


thread_id = '1'

while True:
    user_message = input('type here: ')
    print('user:', user_message)

    if user_message.strip().lower() in ['exit', 'quit', 'bye']:
        break

    config = {'configurable': {'thread_id' : thread_id}}

    response = chatbot.invoke({'messages':[HumanMessage(content=user_message)]}, config=config)

    print('AI:', response['messages'][-1].content)
# Out:
# user: hi my name is deepak
# AI: Hi Deepak, it's nice to meet you! How can I help you today?
# user: what is my name
# AI: Your name is Deepak. You just told me! 😊
# user: i am 30 year old
# AI: It's nice to know that, Deepak! Thanks for sharing. Is there anything else you'd like to tell me or ask me?
# user: what is my age
# AI: You are 30 years old, Deepak. You just told me that.
# user: bye

# %%
chatbot.get_state(config=config)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='hi my name is deepak', additional_kwargs={}, response_metadata={}, id='a5ab6d24-2bc8-443d-a1e8-07641536c0fb'), AIMessage(content="Hi Deepak, it's nice to meet you! How can I help you today?", additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': []}, id='lc_run--019b8002-0175-7c12-b4f2-a642641deb76-0', usage_metadata={'input_tokens': 7, 'output_tokens': 18, 'total_tokens': 25, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='what is my name', additional_kwargs={}, response_metadata={}, id='c76724ec-a913-4267-a3b5-c11fbd1f8e1e'), AIMessage(content='Your name is Deepak. You just told me! 😊', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': []}, id='lc_run--019b8002-1afb-74f2-aff7-c5acdd41bfc7-0', usage_metadata={'input_tokens': 31, 'output_tokens': 11, 'total_tokens': 42, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='i am 30 year old', additional_kwargs={}, response_metadata={}, id='0f253a7e-6307-43dc-a4cb-af45ffa9bad2'), AIMessage(content="It's nice to know that, Deepak! Thanks for sharing. Is there anything else you'd like to tell me or ask me?", additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': []}, id='lc_run--019b8002-4365-7f22-88b8-aea327d02678-0', usage_metadata={'input_tokens': 51, 'output_tokens': 29, 'total_tokens': 80, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='what is my age', additional_kwargs={}, response_metadata={}, id='5ad6fc75-27b1-4593-9847-6e062e230b89'), AIMessage(content='You are 30 years old, Deepak. You just told me that.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': []}, id='lc_run--019b8002-5915-77c2-9469-00d9339edf00-0', usage_metadata={'input_tokens': 86, 'output_tokens': 16, 'total_tokens': 102, 'input_token_details': {'cache_read': 0}})]}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e80a6-fad4-635a-800a-910f68ac8339'}}, metadata={'source': 'loop', 'step': 10, 'parents': {}}, created_at='2026-01-02T18:39:56.942804+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0e80a6-f38d-6df2-8009-51cb978ad335'}}, tasks=(), interrupts=())
